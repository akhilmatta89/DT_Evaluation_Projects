# %% [markdown]
# ### Avacado Project
# ##### Problem Statement:
# Avocado is a fruit consumed by people heavily in the United States.
#
# Content
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold
#
#
# Inspiration /Label
#
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression
#
# Do both tasks in the same .ipynb file and submit at single file.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_squared_error
import joblib
from sklearn.model_selection import cross_val_score,train_test_split,GridSearchCV
from scipy.stats import zscore

# %%
df = pd.read_csv('Avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# - Unnamed column seems to be no use so dropping the column

# %%
df.drop('Unnamed: 0',inplace=True,axis=1)
df.sample()
# Out:
#             Date  AveragePrice  Total Volume       4046      4225      4770  \
# 2322  2015-05-03          0.97     457411.45  271320.49  72324.54  26965.17
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 2322    86801.25    70270.99    16530.26          0.0  conventional  2015
#
#              region
# 2322  SouthCarolina

# %% [markdown]
# ### getting statistical information

# %%
df.shape
# Out:
# (18249, 13)

# %% [markdown]
# - we have 18249 rows and 13 columns inn the dataset

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# - From the above statistical data we can see there is huge outliers present in X-Large bags
# - Higher difference in std and mean in features Total Bags,Small Bags,XLarge Bags

# %% [markdown]
# ### Finding Null values in Dataset

# %%
df.isna().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# ##### Null values visualising in heatmap

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# - No Null values are present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# - we have 3 categeorical variables in the dataset
#     * Date
#     * type
#     * region

# %% [markdown]
# ##### About the features in dataset

# %% [markdown]
# - Date = The date of the observation
# - Averageprice = Average price of single avacado
# - Total Volume = Total number of avacados sold
# - 4046 = Total number of avacados with PLU-4046 sold
# - 4225 = Total number of avacados with PLU-4225 sold
# - 4770 = Total number of avacados with PLU-4770 sold

# %% [markdown]
# - The goal is to predict the average cost of the avocado which is continuous in nature for different types
# - In this dataset most of the columns are float type in nature
# - Date,type,region are categeorical in Nature

# %% [markdown]
# #### Columns in Dataset

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %% [markdown]
# ##### unique elements in each of the columns

# %%
df.nunique()
# Out:
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
sns.countplot(df.type)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
df['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
# Visualization of year value counts
sns.countplot(df.year)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %% [markdown]
# - In 2018 there is very much less data compared to other years

# %%
df['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
plt.figure(figsize=(20,25))
sns.countplot(df.region)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# * There is equal amount of data in every column except WestTexNewMexico

# %% [markdown]
# - Type has 2 unique values (conventional, organic)
# - Year has 4 unique values which are of discrete type(2015,2016,2017,2018)
# - region has 54 unique values

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# ### As the datasett is Huge taking the sample of dataset to see the skewness

# %%
df_sample = df.head(300)

# %% [markdown]
# #### Checking for skewness

# %%
num_cols = ['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']
plt.figure(figsize=(20,30),facecolor='white')
plotnum = 1
for i in num_cols:
    if plotnum <=10:
        plt.subplot(4,2,plotnum)
        sns.distplot(df_sample[i])
        plt.xlabel(i,fontsize=10)
    plotnum+=1
plt.show()

# %% [markdown]
# - Total Volume,4046,4225,4770 has the binomial distribution.
# - Total Bags,Small bags,Large Bags, XLarge Bags has the skewness presentin it.

# %% [markdown]
# #### Comparision of year and 4046,4225,4770

# %%
y_cols = df[['4046','4225','4770']]
x_cols = df['year']
plt.figure(figsize=(10,15),facecolor='white')
plotnum = 1
for cols in y_cols:
    plt.subplot(3,1,plotnum)
    sns.barplot(x_cols,y_cols[cols])
    plt.xlabel('year',fontsize=20)
    plt.ylabel(cols,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# - PLU 4046 has grown over the 4 years
# - compared to PLU-4225 production PLU-4046 is more
# - PLU-4770 is least produced

# %% [markdown]
# #### Comparision of different PLU's and type

# %%
y_cols = df[['4046','4225','4770']]
x_cols = df['type']
plt.figure(figsize=(10,15),facecolor='white')
plotnum = 1
for cols in y_cols:
    plt.subplot(3,1,plotnum)
    sns.barplot(x_cols,y_cols[cols])
    plt.xlabel('type',fontsize=20)
    plt.ylabel(cols,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# - Production of conventional_type is more in cases 4046,4225,4770.
# - By this we can say less production high demand the organic rates we can assume as higher

# %% [markdown]
# #### Comparision of avaerage prices in different years

# %%
y_cols = df['AveragePrice']
x_cols = df[['year']]
plt.figure(figsize=(5,5),facecolor='white')
plotnum = 1
for cols in x_cols:
    plt.subplot(1,1,plotnum)
    sns.barplot(x_cols[cols],y_cols)
    plt.xlabel(cols,fontsize=15)
    plt.ylabel('AveragePrice',fontsize=15)
    plotnum+=1
plt.show()

# %% [markdown]
# - From this graph we can say that there is more avarage price in 2017 years

# %%
df.groupby('year')['AveragePrice'].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# - There is some dip in AveragePrice in 2016 and hike in AveragePrice in 2017

# %%
# Values of the year and average price
df.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.375590
# 2016    1.338640
# 2017    1.515128
# 2018    1.347531
# Name: AveragePrice, dtype: float64

# %%
df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %% [markdown]
# - 2018 there is less production in convetional and organic types

# %% [markdown]
# #### extracting Date and month from Date feature not creating year because it is already present in dataset

# %%
df['Date'] = pd.to_datetime(df['Date'])     # changing the object type to datetime type
df['Day'] = df['Date'].apply(lambda d:d.day)# Extracting the date and adding to df
df['Month'] = df['Date'].apply(lambda m:m.month)#Extracting month and adding to df

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Day  Month
# 0  Albany   27     12
# 1  Albany   20     12
# 2  Albany   13     12
# 3  Albany    6     12
# ...

# %%
plt.figure(figsize=(16,10),facecolor='white')
sns.lineplot(x='Month',y='AveragePrice', hue = 'type',data=df)
plt.show()

# %% [markdown]
# - There is hike in 8-10 th month for both organic and conventional types

# %% [markdown]
# #### Dropping some of the columns
# ###### Observation:
# - As we observe the sum of 4046,4225,4770,Total Bags is Total Volume Column
# - The sum of Small Bags,Large Bags,XLarge Bags is Total Bags feature

# %%
df.drop(columns=['Date','Total Volume','Total Bags'],inplace=True,axis=1)
df.head()
# Out:
#    AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0          1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1          1.35   674.28   44638.81   58.33     9408.07       97.49
# 2          0.93   794.70  109149.67  130.50     8042.21      103.14
# 3          1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4          1.28   941.48   43838.39   75.78     5986.26      197.69
#
#    XLarge Bags          type  year  region  Day  Month
# 0          0.0  conventional  2015  Albany   27     12
# 1          0.0  conventional  2015  Albany   20     12
# 2          0.0  conventional  2015  Albany   13     12
# 3          0.0  conventional  2015  Albany    6     12
# 4          0.0  conventional  2015  Albany   29     11

# %%
#### Finding outliers in the dataset
def check_outliers(data_f):
    plt.figure(figsize=(20,25),facecolor='white')
    plotnum = 1
    for feature in data_f.drop(columns=['year','type','region','AveragePrice'],axis=1):
        if plotnum <= 16:
            plt.subplot(5,5,plotnum)
            sns.boxplot(data_f[feature])
            plt.xlabel(feature)
        plotnum+=1
    plt.show()
check_outliers(df)

# %% [markdown]
# - Each column here has the ouliers except Day and Month

# %% [markdown]
# ### Removing outliers using z-score method

# %%
df_2 = df.drop(columns=['year','type','region','AveragePrice'],axis=1).copy()
df_2.sample()
# Out:
#         4046    4225  4770  Small Bags  Large Bags  XLarge Bags  Day  Month
# 11935  42.26  156.72   0.0     1687.65         0.0          0.0   11     12

# %%
# Applying z-score method
from scipy.stats import zscore
zscore_abs = np.abs(zscore(df_2))
#THreshold is taken as +3/-3
zdf = df_2[(zscore_abs < 3).all(axis=1)]

# %%
df_2.shape
# Out:
# (18249, 8)

# %%
zdf.shape
# Out:
# (17782, 8)

# %%
print('The data loss sfter using z-score method is ',(18249-17782)/18249 * 100)
# Out:
# The data loss sfter using z-score method is  2.55904433119623

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum = 1
for feature in zdf:
    if plotnum <= 16:
        plt.subplot(5,5,plotnum)
        sns.boxplot(zdf[feature])
        plt.xlabel(feature)
    plotnum+=1
plt.show()

# %% [markdown]
# - Some outliers has been reduced from dataset

# %% [markdown]
# ### IQR METHOD

# %%
df_2.head()
# Out:
#       4046       4225    4770  Small Bags  Large Bags  XLarge Bags  Day  Month
# 0  1036.74   54454.85   48.16     8603.62       93.25          0.0   27     12
# 1   674.28   44638.81   58.33     9408.07       97.49          0.0   20     12
# 2   794.70  109149.67  130.50     8042.21      103.14          0.0   13     12
# 3  1132.00   71976.41   72.58     5677.40      133.76          0.0    6     12
# 4   941.48   43838.39   75.78     5986.26      197.69          0.0   29     11

# %%
# Creating a function to remove outlier
"""Takes the dataframe and removed the outliers and will return back"""
outlier_index = np.array([])
for column in df_2:
    q1 = df_2[column].quantile(0.25)
    q3 = df_2[column].quantile(0.75)
    IQR = q3-q1
    col = df_2[column]
    indx = col[(col > q3+1.5*IQR) | (col < q1-1.5*IQR)].index
    outlier_index = np.append(outlier_index,indx)
outlier_index
# Out:
# array([   52.,    54.,    55., ...,  9121., 18220., 18232.])

# %%
df_2 = df_2.drop(outlier_index)
df_2.shape
# Out:
# (11747, 8)

# %%
print('The data loss sfter using IQR method is ',(18249-11747)/18249 * 100)
# Out:
# The data loss sfter using IQR method is  35.62934955340019

# %% [markdown]
# - IQR METHOD REULTS ARE NOT IN ACCEPTABLE RANGE

# %%
### Using zscore method to remove outliers
df.head()
# Out:
#    AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0          1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1          1.35   674.28   44638.81   58.33     9408.07       97.49
# 2          0.93   794.70  109149.67  130.50     8042.21      103.14
# 3          1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4          1.28   941.48   43838.39   75.78     5986.26      197.69
#
#    XLarge Bags          type  year  region  Day  Month
# 0          0.0  conventional  2015  Albany   27     12
# 1          0.0  conventional  2015  Albany   20     12
# 2          0.0  conventional  2015  Albany   13     12
# 3          0.0  conventional  2015  Albany    6     12
# 4          0.0  conventional  2015  Albany   29     11

# %%
dropindx = df.index.difference(zdf.index)

# %%
df.drop(dropindx,inplace=True)
df
# Out:
#        AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0              1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1              1.35   674.28   44638.81   58.33     9408.07       97.49
# 2              0.93   794.70  109149.67  130.50     8042.21      103.14
# 3              1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4              1.28   941.48   43838.39   75.78     5986.26      197.69
# ...             ...      ...        ...     ...         ...         ...
# 18244          1.63  2046.96    1529.20    0.00    13066.82      431.85
# 18245          1.71  1191.70    3431.50    0.00     8940.04      324.80
# 18246          1.87  1191.92    2452.79  727.94     9351.80       42.31
# 18247          1.93  1527.63    2981.04  727.01    10919.54       50.00
# 18248          1.62  2894.77    2356.13  224.53    11988.14       26.01
#
#        XLarge Bags          type  year            region  Day  Month
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# ### Checking for skewness

# %%
df.skew()
# Out:
# AveragePrice    0.560969
# 4046            4.928850
# 4225            4.472729
# 4770            5.137120
# Small Bags      4.238647
# Large Bags      5.072468
# XLarge Bags     6.159391
# year            0.220792
# Day             0.011251
# Month           0.098217
# dtype: float64

# %% [markdown]
# ### Normalizing Data using PowerTransformer

# %%
from sklearn.preprocessing import PowerTransformer
power_transform = PowerTransformer(method = 'yeo-johnson', standardize=True)
nor_df = df.drop(columns=['year','type','region','AveragePrice'],axis=1)
transformed= power_transform.fit_transform(nor_df)
transformed = pd.DataFrame(transformed, columns=nor_df.columns)
transformed
# Out:
#            4046      4225      4770  Small Bags  Large Bags  XLarge Bags  \
# 0     -0.649918  0.358278 -0.212550   -0.337064   -0.775214    -0.675702
# 1     -0.770067  0.276355 -0.165117   -0.301038   -0.765237    -0.675702
# 2     -0.724508  0.656010  0.034215   -0.364044   -0.752534    -0.675702
# 3     -0.625017  0.475615 -0.110976   -0.500341   -0.693012    -0.675702
# 4     -0.677083  0.268966 -0.100289   -0.479918   -0.600755    -0.675702
# ...         ...       ...       ...         ...         ...          ...
# 17777 -0.454078 -0.922232 -1.224990   -0.165765   -0.405895    -0.675702
# 17778 -0.610403 -0.665649 -1.224990   -0.321645   -0.478556    -0.675702
# 17779 -0.610350 -0.774395  0.455355   -0.303466   -0.945246    -0.675702
# 17780 -0.539211 -0.711605  0.455045   -0.240252   -0.910471    -0.675702
# 17781 -0.351503 -0.787209  0.168008   -0.201685   -1.042930    -0.675702
#
#             Day     Month
# 0      1.227516  1.491714
# 1      0.538250  1.491714
# ...

# %%
transformed.skew()
# Out:
# 4046          -0.038259
# 4225          -0.043246
# 4770           0.028015
# Small Bags    -0.024657
# Large Bags    -0.110061
# XLarge Bags    0.860603
# Day           -0.209306
# Month         -0.149112
# dtype: float64

# %%
transformed.index = df.index
skewed = ['4046','4225','4770','Small Bags','Large Bags','XLarge Bags']
df[skewed] = transformed[skewed]
df.skew()
# Out:
# AveragePrice    0.560969
# 4046           -0.038259
# 4225           -0.043246
# 4770            0.028015
# Small Bags     -0.024657
# Large Bags     -0.110061
# XLarge Bags     0.860603
# year            0.220792
# Day             0.011251
# Month           0.098217
# dtype: float64

# %% [markdown]
# #### Once gain checking for skewness

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum = 1
for i in df[['4046','4225','4770','Small Bags','Large Bags','XLarge Bags']]:
    if plotnum <=10:
        plt.subplot(4,4,plotnum)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=10)
    plotnum+=1
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17782 entries, 0 to 17781
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  17782 non-null  float64
#  1   4046          17782 non-null  float64
#  2   4225          17782 non-null  float64
#  3   4770          17782 non-null  float64
#  4   Small Bags    17782 non-null  float64
#  5   Large Bags    17782 non-null  float64
#  6   XLarge Bags   17782 non-null  float64
#  7   type          17782 non-null  object
#  8   year          17782 non-null  int64
#  9   region        17782 non-null  object
#  10  Day           17782 non-null  int64
#  11  Month         17782 non-null  int64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Label Encoding for categeorical variables

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_col = ['type','region']
for i in cat_col:
    df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17782 entries, 0 to 17781
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  17782 non-null  float64
#  1   4046          17782 non-null  float64
#  2   4225          17782 non-null  float64
#  3   4770          17782 non-null  float64
#  4   Small Bags    17782 non-null  float64
#  5   Large Bags    17782 non-null  float64
#  6   XLarge Bags   17782 non-null  float64
#  7   type          17782 non-null  int64
#  8   year          17782 non-null  int64
#  9   region        17782 non-null  int64
#  10  Day           17782 non-null  int64
#  11  Month         17782 non-null  int64
# dtypes: float64(7), int64(5)
# memory usage: 1.6 MB

# %% [markdown]
# ### Finding the correlation

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='RdBu',vmin=-1,vmax=+1,linewidths=2)
plt.show()

# %%
df.corr()['AveragePrice'].sort_values(ascending=False).drop(['AveragePrice']).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - type,month,year,day,region are positively correlated
# - XLargeBags,4225,LargeBags,4225,Large Bags,4770,Small Bags,4046 are negatively correlated

# %% [markdown]
# ### Standardization

# %%
# splitting the data
x = df.drop('AveragePrice',axis=1)
y = df['AveragePrice']

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
scaled_x = scalar.fit_transform(x)

# %% [markdown]
# ### Using Variation inflation factor for checking multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_VIF(scaled_x):
    #Calculating VIF
    vif = pd.DataFrame()
    vif['Features'] = x.columns
    vif['VIF'] = [variance_inflation_factor(scaled_x,i) for i in range(scaled_x.shape[1])]
    return vif
vif = calc_VIF(scaled_x)

# %%
vif
# Out:
#        Features       VIF
# 0          4046  3.723160
# 1          4225  4.139977
# 2          4770  3.940502
# 3    Small Bags  4.103569
# 4    Large Bags  1.866024
# 5   XLarge Bags  2.039339
# 6          type  3.498746
# 7          year  1.359839
# 8        region  1.079283
# 9           Day  1.000506
# 10        Month  1.051207

# %% [markdown]
# ### Selecting kbest features

# %%
from sklearn.feature_selection import SelectKBest, f_classif
k_best_features = SelectKBest(score_func=f_classif, k=11)
best_fit = k_best_features.fit(x,y)
dfscores = pd.DataFrame(best_fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(22,'Score'))
# Out:
#         Feature      Score
# 6          type  49.966168
# 0          4046  36.480181
# 2          4770  27.651101
# 3    Small Bags  25.039951
# 4    Large Bags  23.354747
# 1          4225  21.772853
# 5   XLarge Bags  15.065353
# 7          year   3.163539
# 10        Month   2.850599
# 8        region   1.291093
# 9           Day   1.249095

# %% [markdown]
# - selecting best features based on score
# - Dropping the least scores from the datase

# %%
x_best = x.drop(columns=['region','Day'])

# %%
x_best_sclaed = scalar.fit_transform(x_best)

# %% [markdown]
# ##### As the output data is continuous we need are going with regression models

# %%
maxAcc = 0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x_best_sclaed,y,test_size = .33, random_state = i)
    modRF =  RandomForestRegressor()
    modRF.fit(x_train,y_train)
    pred = modRF.predict(x_test)
    acc  = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print(f"Best Accuracy is: {maxAcc} on random_state: {maxRS}")
# Out:
# Best Accuracy is: 0.8722154989831881 on random_state: 11

# %%
models= [RandomForestRegressor(),DecisionTreeRegressor(),XGBRegressor(),Ridge(),SVR(),AdaBoostRegressor(),KNeighborsRegressor()]
x_train,x_test,y_train,y_test = train_test_split(x_best_sclaed,y,test_size=.33,random_state=11)

def compare_models():
    for model in models:
        
        model.fit(x_train,y_train)
        model_predict = model.predict(x_test)
        score_r2 = r2_score(y_test, model_predict)
        mean_error = mean_squared_error(y_test, model_predict)
        crossval_score = cross_val_score(model,x_best_sclaed,y,cv=4).mean()
        print("R2 score of the model : ",model,"=",round(score_r2*100,1),"%")
        print("mean squared error for model : ",model,"=",mean_error)
        print("cross val score for model : ",model, "=",crossval_score)
        print('_______________________________________________')
compare_models()
# Out:
# R2 score of the model :  RandomForestRegressor() = 87.2 %
# mean squared error for model :  RandomForestRegressor() = 0.020885537812233772
# cross val score for model :  RandomForestRegressor() = 0.07634926894166685
# _______________________________________________
# R2 score of the model :  DecisionTreeRegressor() = 71.3 %
# mean squared error for model :  DecisionTreeRegressor() = 0.04675689214516954
# cross val score for model :  DecisionTreeRegressor() = -0.41904736510432555
# _______________________________________________
# R2 score of the model :  XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
# ...

# %%
from sklearn.model_selection import ShuffleSplit
def compare_models():
    for model in models:
        
        model.fit(x_train,y_train)
        model_predict = model.predict(x_test)
        score_r2 = r2_score(y_test, model_predict)
        mean_error = mean_squared_error(y_test, model_predict)
        crossval_score = cross_val_score(model,x_best_sclaed,y,cv=ShuffleSplit(5)).mean()
        print("R2 score of the model : ",model,"=",round(score_r2*100,1),"%")
        print("mean squared error for model : ",model,"=",mean_error)
        print("Root Mean squared error is : ", np.sqrt(mean_error))
        print("cross val score for model : ",model, "=",crossval_score)
        print('_______________________________________________')
compare_models()
# Out:
# R2 score of the model :  RandomForestRegressor() = 87.1 %
# mean squared error for model :  RandomForestRegressor() = 0.021005728730618504
# Root Mean squared error is :  0.14493353211254636
# cross val score for model :  RandomForestRegressor() = 0.8741791488233016
# _______________________________________________
# R2 score of the model :  DecisionTreeRegressor() = 71.3 %
# mean squared error for model :  DecisionTreeRegressor() = 0.046655103084000685
# Root Mean squared error is :  0.21599792379557883
# cross val score for model :  DecisionTreeRegressor() = 0.7432684143701433
# _______________________________________________
# R2 score of the model :  XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
# ...

# %% [markdown]
# - Going with RandomForestRegressor as it is giving good r2_score and least root mean squared error

# %% [markdown]
# ### HyperParameter Tuning

# %%
random_forest_params = {'n_estimators':[30,60,80],
                   'max_depth':[10,20,40],
                   'min_samples_leaf':[5,10,20],
                   'min_samples_split':[5,10],
                   'max_features':['auto','sqrt','log2'],
                   'criterion':['mse','mae']
    }
grid_classifier = GridSearchCV(RandomForestRegressor(),random_forest_params,cv=5,n_jobs=-1,verbose=1)
grid_classifier.fit(x_train,y_train)
print(f"The best parameters are {grid_classifier.best_params_}")
print(f"The best Score is {grid_classifier.best_score_}")
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# The best parameters are {'criterion': 'mse', 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 80}
# The best Score is 0.8270257430414654

# %%
Best_mod1 = RandomForestRegressor(n_estimators=60,criterion='mse',max_depth=20,max_features='auto',min_samples_leaf=5,min_samples_split=10)
Best_mod1.fit(x_train,y_train)
rfrpred = Best_mod1.predict(x_test)
acc = r2_score(y_test,rfrpred)
print(acc*100)
# Out:
# 85.06114619059794

# %% [markdown]
# #### saving the Model

# %%
import joblib
joblib.dump(Best_mod1,"Avocado_model.pkl")
# Out:
# ['Avocado_model.pkl']

# %% [markdown]
# #### Loading the model

# %%
mod = joblib.load("Avocado_model.pkl")
print(mod.predict(x_test))
# Out:
# [1.38430919 1.13950446 1.11762684 ... 1.22144562 2.05760226 1.35015218]

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, rfrpred, c='red')
plt.yscale('linear')
plt.xscale('linear')

p1 = max(max(rfrpred), max(y_test))
p2 = min(min(rfrpred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Actual Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()
